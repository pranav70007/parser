# %%
#from doctr.io import DocumentFile
from doctr.models import ocr_predictor

model = ocr_predictor(pretrained=True)
# PDF
doc = DocumentFile.from_images("image.png")
# Analyze
result = model(doc)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 #from doctr.io import DocumentFile
# ----> 2 from doctr.models import ocr_predictor
#       4 model = ocr_predictor(pretrained=True)
#       5 # PDF
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/doctr/__init__.py:1
# ----> 1 from . import io, models, datasets, contrib, transforms, utils
#       2 from .file_utils import is_tf_available, is_torch_available
#       3 from .version import __version__  # noqa: F401
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/doctr/io/__init__.py:1
# ----> 1 from .elements import *
#       2 from .html import *
#       3 from .image import *
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/doctr/io/elements.py:20
#      18 from doctr.file_utils import requires_package
#      19 from doctr.utils.common_types import BoundingBox
# ---> 20 from doctr.utils.geometry import resolve_enclosing_bbox, resolve_enclosing_rbbox
#      21 from doctr.utils.reconstitution import synthesize_kie_page, synthesize_page
#      22 from doctr.utils.repr import NestedObject
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/doctr/utils/__init__.py:3
#       1 from .common_types import *
#       2 from .data import *
# ----> 3 from .geometry import *
#       4 from .metrics import *
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/doctr/utils/geometry.py:10
#       7 from math import ceil
#       8 from typing import List, Optional, Tuple, Union
# ---> 10 import cv2
#      11 import numpy as np
#      13 from .common_types import BoundingBox, Polygon4P
#
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory
